# %% [markdown]
# <a href="https://colab.research.google.com/github/Ihsan149/IE803_Spring_2024/blob/main/TSM_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')

# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# /
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# 'Colab Notebooks'   HAR.zip  'My Drive'

# %%
# !pip install tensorboardx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 1.3 MB/s eta 0:00:00
# ...

# %%
# !unzip /content/gdrive/MyDrive/HAR.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: HAR/UCFCrime/frames/3/img_00540.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00541.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00542.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00543.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00544.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00545.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00546.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00547.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00548.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00549.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00550.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00551.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00552.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00553.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00554.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00555.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00556.jpg
#   inflating: HAR/UCFCrime/frames/3/img_00557.jpg
# ...

# %%
# !python /HAR/main.py ucfcrime RGB --arch resnet50 --num_segments 8 --gd 20 --lr 0.001 --lr_steps 10 20 --epochs 15 --batch-size 8 -j 16 --dropout 0.8 --consensus_type=avg --eval-freq=1 --shift --shift_div=8 --shift_place=blockres --pretrain=imagenet
# Out:
# ucfcrime: 2 classes
# storing name: TSM_ucfcrime_RGB_resnet50_shift8_blockres_avg_segment8_e15
#
#     Initializing TSN with base model: resnet50.
#     TSN Configurations:
#         input_modality:     RGB
#         num_segments:       8
#         new_length:         1
#         consensus_module:   avg
#         dropout_ratio:      0.8
#         img_feature_dim:    256
#
# => base model: resnet50
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# ...

# %%
# !python /HAR/main.py ucfcrime RGB --arch mobilenetv2 --num_segments 8 --gd 20 --lr 0.001 --lr_steps 10 20 --epochs 25 --batch-size 32 -j 16 --dropout 0.8 --consensus_type=avg --eval-freq=1 --shift --shift_div=8 --shift_place=blockres --pretrain=imagenet --dense
# Out:
# ucfcrime: 2 classes
# storing name: TSM_ucfcrime_RGB_mobilenetv2_shift8_blockres_avg_segment8_e25_dense
# creating folder log/TSM_ucfcrime_RGB_mobilenetv2_shift8_blockres_avg_segment8_e25_dense
# creating folder checkpoint/TSM_ucfcrime_RGB_mobilenetv2_shift8_blockres_avg_segment8_e25_dense
#
#     Initializing TSN with base model: mobilenetv2.
#     TSN Configurations:
#         input_modality:     RGB
#         num_segments:       8
#         new_length:         1
#         consensus_module:   avg
#         dropout_ratio:      0.8
#         img_feature_dim:    256
#
# => base model: mobilenetv2
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# ...

# %%
# !python /HAR/test_models.py ucfcrime \
--weights=/checkpoint/TSM_ucfcrime_RGB_mobilenetv2_shift8_blockres_avg_segment8_e25_dense/ckpt.best.pth.tar --test_segments=8 --batch_size=1
# Out:
# ucfcrime: 2 classes
# => shift: True, shift_div: 8, shift_place: blockres
#
#     Initializing TSN with base model: mobilenetv2.
#     TSN Configurations:
#         input_modality:     RGB
#         num_segments:       8
#         new_length:         1
#         consensus_module:   avg
#         dropout_ratio:      0.8
#         img_feature_dim:    256
#
# => base model: mobilenetv2
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# video number:4
# ...
